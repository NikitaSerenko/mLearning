# %% [markdown]
# # CIFAR Conv Net
#
# И так, в этом ноутбуке Вы сделаете превую в своей жизни сверточную сеть! На сложном датасете. Cкачайте его кстати,

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from cifar import load_CIFAR10
plt.rcParams['figure.figsize'] = (10.0, 8.0) 

cifar10_dir = './cifar10/cifar-10-batches-py'
X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

# %%
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
num_classes = len(classes)
samples_per_class = 7
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(y_train == y)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(X_train[idx].astype('uint8').transpose(1, 2, 0))
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %% [markdown]
# <h1 align="center">First of all -- Checking Questions</h1>
#
# **Вопрос 1**: Чем отличаются современные сверточные сети от сетей 5 летней давности?
#
# <Ответ> Более сложные архитектуры с большим количество блоков. Batch Normalization, Shortcuts, DataAugmentation для борьбы с затуханием градиентов и т.п.
#
# **Вопрос 2**: Какие неприятности могут возникнуть во время обучения современных нейросетей?
#
# <Ответ>  Переобучение, затухание градиента.
#
#
# **Вопрос 3**: У вас есть очень маленький датасет из 100 картинок, классификация, но вы очень хотите использовать нейросеть, какие неприятности вас ждут и как их решить? что делать если первый вариант  решения не заработает?
#
# <Ответ> При использовании маленьких выборов сеть склонна к переобучению.  Использовать DropOut, DropConnect, Data Augmentation,  Regularization.
#
# **Вопрос 4**: Как сделать стайл трансфер для музыки? oO
#
# <Ответ> Нарезать спектрограмму звука по времени. И применить аналогичную схему как для картинок.

# %%
import lasagne
from theano import tensor as T
from lasagne.nonlinearities import *
input_X = T.tensor4("X")
target_y = T.vector("target Y integer",dtype='int32')
# Out:
# Using cuDNN version 5110 on context None
# Mapped name None to device cuda0: GRID K520 (0000:00:03.0)

# %%
def get_residual(in_l, n):
    lay1 = lasagne.layers.Conv2DLayer(in_l, n, 3, pad='same')
    lay2 = lasagne.layers.batch_norm(lay1)
    lay3 = lasagne.layers.Conv2DLayer(lay2, n, 3, pad='same')
    lay4 = lasagne.layers.batch_norm(lay3) 
    lay5 = lasagne.layers.ElemwiseSumLayer([lay2, lay4])
    lay6 = lasagne.layers.NonlinearityLayer(lay5)
    return lay6

# %% [markdown]
# ### Соберите нейронку:
# - Many times x (Conv+Pool)
# - Many small convolutions like 3x3
# - Batch Norm
# - Residual Connection
# - Data Augmentation
# - Learning rate Schedule
# - ...
#
# ### Для вдохновения
# - http://torch.ch/blog/2015/07/30/cifar.html
# - https://github.com/szagoruyko/wide-residual-networks
#
# ### Самое интересное
# - Для сдачи задания нужно набрать на точность тесте > **92.5**% (это займет много времени, торопитесь :) )
# - Для получения бонусных баллов > **95.0**%
# - Будет очень хорошо если вы придумаете свою архитектуру или сможете обучить что-то из вышеперечисленного :)
# - А для обучения всего этого добра вам будет куда удобнее использовать GPU на Amazon
#     - Инструкция https://github.com/persiyanov/ml-mipt/tree/master/amazon-howto
#     - Вам помогут tmux, CuDNN, ssh tunnel, nvidia-smi, ...
#     - Have fun :)

# %%
net = lasagne.layers.InputLayer(shape=(None, 3, 32, 32), input_var=input_X)
input_size = 32
l1 = get_residual(net, input_size)
l2 = get_residual(l1, input_size * 2)
net = lasagne.layers.MaxPool2DLayer(l2, pool_size=2)
net = lasagne.layers.DropoutLayer(net, 0.5)
l3 = get_residual(net, input_size * 4)
net = lasagne.layers.MaxPool2DLayer(l3, pool_size=2)
l4 = get_residual(net, input_size * 8)
net = lasagne.layers.MaxPool2DLayer(l4, pool_size=2)
net = lasagne.layers.DenseLayer(net, num_units=512)
net = lasagne.layers.batch_norm(net)
net = lasagne.layers.DropoutLayer(net, 0.5)
net = lasagne.layers.DenseLayer(net, num_units=512)
net = lasagne.layers.batch_norm(net)
net = lasagne.layers.DropoutLayer(net, 0.5)
net = lasagne.layers.DenseLayer(net, num_units=10, nonlinearity=softmax)

# %%
y_predicted = lasagne.layers.get_output(net)
all_weights = lasagne.layers.get_all_params(net, trainable=True)

# %%
loss = lasagne.objectives.categorical_crossentropy(y_predicted, target_y).mean()
accuracy = lasagne.objectives.categorical_accuracy(y_predicted, target_y).mean()
all_layers = lasagne.layers.get_all_layers(net)
l2_penalty = lasagne.regularization.regularize_layer_params(all_layers, lasagne.regularization.l2) * 0.0001
loss = loss + l2_penalty

learning_rate_ = 0.01
shared_learning_rate_ = theano.shared(lasagne.utils.floatX(learning_rate_))

updates = lasagne.updates.momentum(loss, all_weights, learning_rate=shared_learning_rate_)

# %%
train_fun = theano.function([input_X, target_y], [loss, accuracy], updates=updates, 
                            allow_input_downcast=True)
accuracy_fun = theano.function([input_X, target_y], accuracy, allow_input_downcast=True)

# %% [markdown]
# ### Вот и всё, пошли её учить

# %%
def iterate_minibatches(inputs, targets, batchsize, shuffle=False):
    assert len(inputs) == len(targets)
    if shuffle:
        indices = np.arange(len(inputs))
        np.random.shuffle(indices)
    for start_idx in range(0, len(inputs) - batchsize + 1, batchsize):
        if shuffle:
            excerpt = indices[start_idx:start_idx + batchsize]
        else:
            excerpt = slice(start_idx, start_idx + batchsize)
        yield inputs[excerpt], targets[excerpt]

# %%
# ############################# Batch iterator ###############################
# from https://github.com/Lasagne/Recipes/blob/master/papers/deep_residual_learning/Deep_Residual_Learning_CIFAR-10.py

def iterate_minibatches(inputs, targets, batchsize, shuffle=False, augment=False):
    assert len(inputs) == len(targets)
    if shuffle:
        indices = np.arange(len(inputs))
        np.random.shuffle(indices)
    for start_idx in range(0, len(inputs) - batchsize + 1, batchsize):
        if shuffle:
            excerpt = indices[start_idx:start_idx + batchsize]
        else:
            excerpt = slice(start_idx, start_idx + batchsize)
        if augment:
            # as in paper : 
            # pad feature arrays with 4 pixels on each side
            # and do random cropping of 32x32
            padded = np.pad(inputs[excerpt], ((0, 0), (0, 0), (4, 4), (4, 4)), mode='constant')
            random_cropped = np.zeros(inputs[excerpt].shape, dtype=np.float32)
            crops = np.random.randint(0, 9, size=(batchsize, 2))
            for r in range(batchsize):
                random_cropped[r, :, :, :] = padded[r, :, crops[r, 0]:(crops[r, 0] + 32), crops[r, 1]:(crops[r, 1] + 32)]
            inp_exc = random_cropped
        else:
            inp_exc = inputs[excerpt]

        yield inp_exc, targets[excerpt]

# %%
X_train = np.array(X_train, dtype = np.float32)
X_test = np.array(X_test, dtype = np.float32)
y_train = np.array(y_train, dtype = np.int32)
y_test = np.array(y_test, dtype = np.int32)

# %% [markdown]
# # Процесс обучения

# %%
import time

num_epochs = 25 #количество проходов по данным

batch_size = 50 #размер мини-батча

for epoch in range(num_epochs):
    if epoch % 10 == 0 and epoch > 0:
        learning_rate__ = shared_learning_rate_.get_value() / 2
        shared_learning_rate_.set_value(lasagne.utils.floatX(learning_rate__))

    # In each epoch, we do a full pass over the training data:
    train_err = 0
    train_acc = 0
    train_batches = 0
    start_time = time.time()
    for batch in iterate_minibatches(X_train, y_train, batch_size, shuffle=True, augment=True):
        inputs, targets = batch
        train_err_batch, train_acc_batch = train_fun(inputs, targets)
        train_err += train_err_batch
        train_acc += train_acc_batch
        train_batches += 1

    # And a full pass over the validation data:
    val_acc = 0
    val_batches = 0
    for batch in iterate_minibatches(X_test, y_test, batch_size):
        inputs, targets = batch
        val_acc += accuracy_fun(inputs, targets)
        val_batches += 1

    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(epoch, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration):\t\t{:.6f}".format(train_err / train_batches))
    print("  train accuracy:\t\t{:.2f} %".format(train_acc / train_batches * 100))
    print("  validation accuracy:\t\t{:.2f} %".format(val_acc / val_batches * 100))
# Out:
# Epoch 0 of 25 took 174.735s
#   training loss (in-iteration):		2.958648
#   train accuracy:		45.32 %
#   validation accuracy:		55.31 %
# Epoch 1 of 25 took 174.940s
#   training loss (in-iteration):		2.104458
#   train accuracy:		58.34 %
#   validation accuracy:		62.31 %
# Epoch 2 of 25 took 174.047s
#   training loss (in-iteration):		1.784540
#   train accuracy:		65.04 %
#   validation accuracy:		66.93 %
# Epoch 3 of 25 took 174.847s
#   training loss (in-iteration):		1.683353
#   train accuracy:		68.65 %
#   validation accuracy:		69.45 %
# Epoch 4 of 25 took 174.357s
#   training loss (in-iteration):		1.587732
#   train accuracy:		71.37 %
#   validation accuracy:		72.81 %
# Epoch 5 of 25 took 174.955s
#   training loss (in-iteration):		1.526690
#   train accuracy:		73.70 %
#   validation accuracy:		72.92 %
# Epoch 6 of 25 took 174.940s
#   training loss (in-iteration):		1.456633
#   train accuracy:		75.15 %
#   validation accuracy:		75.58 %
# Epoch 7 of 25 took 175.024s
#   training loss (in-iteration):		1.403675
#   train accuracy:		76.34 %
#   validation accuracy:		74.09 %
# Epoch 8 of 25 took 174.620s
#   training loss (in-iteration):		1.390482
#   train accuracy:		76.88 %
#   validation accuracy:		75.87 %
# Epoch 9 of 25 took 174.804s
#   training loss (in-iteration):		1.363054
#   train accuracy:		77.04 %
#   validation accuracy:		75.87 %
# Epoch 10 of 25 took 174.302s
#   training loss (in-iteration):		1.213434
#   train accuracy:		79.99 %
#   validation accuracy:		78.75 %
# Epoch 11 of 25 took 174.838s
#   training loss (in-iteration):		1.107463
#   train accuracy:		81.21 %
#   validation accuracy:		79.67 %
# Epoch 12 of 25 took 174.046s
#   training loss (in-iteration):		1.053174
#   train accuracy:		82.40 %
#   validation accuracy:		80.11 %
# Epoch 13 of 25 took 175.024s
#   training loss (in-iteration):		1.023492
#   train accuracy:		82.91 %
#   validation accuracy:		80.92 %
# Epoch 14 of 25 took 174.847s
#   training loss (in-iteration):		0.999424
#   train accuracy:		83.13 %
#   validation accuracy:		81.08 %
# Epoch 15 of 25 took 174.942s
#   training loss (in-iteration):		0.983684
#   train accuracy:		83.56 %
#   validation accuracy:		80.46 %
# Epoch 16 of 25 took 175.134s
#   training loss (in-iteration):		0.884532
#   train accuracy:		83.72 %
#   validation accuracy:		80.79 %
# Epoch 17 of 25 took 174.372s
#   training loss (in-iteration):		0.858532
#   train accuracy:		83.57 %
#   validation accuracy:		81.23 %
# Epoch 18 of 25 took 174.836s
#   training loss (in-iteration):		0.841946
#   train accuracy:		83.89 %
#   validation accuracy:		81.03 %
# Epoch 19 of 25 took 174.849s
#   training loss (in-iteration):		0.828423
#   train accuracy:		84.34 %
#   validation accuracy:		81.43 %
# Epoch 20 of 25 took 175.045s
#   training loss (in-iteration):		0.801483
#   train accuracy:		86.46 %
#   validation accuracy:		83.89 %
# Epoch 21 of 25 took 174.894s
#   training loss (in-iteration):		0.794751
#   train accuracy:		87.55 %
#   validation accuracy:		82.96 %
# Epoch 22 of 25 took 175.104s
#   training loss (in-iteration):		0.761694
#   train accuracy:		87.93 %
#   validation accuracy:		83.15 %
# Epoch 23 of 25 took 174.862s
#   training loss (in-iteration):		0.752652
#   train accuracy:		88.02 %
#   validation accuracy:		82.84 %
# Epoch 24 of 25 took 174.735s
#   training loss (in-iteration):		0.735085
#   train accuracy:		89.47 %
#   validation accuracy:		82.53 %

# %%
test_acc = 0
test_batches = 0
for batch in iterate_minibatches(X_test, y_test, 500):
    inputs, targets = batch
    acc = accuracy_fun(inputs, targets)
    test_acc += acc
    test_batches += 1
print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_acc / test_batches * 100))

if test_acc / test_batches * 100 > 92.5:
    print("Achievement unlocked: колдун 80 уровня")
else:
    print("Нужно больше магии!")
# Out:
# Final results:
#   test accuracy:		83.85 %
# Нужно больше магии!

# %% [markdown]
# ## Заполните форму
#
# https://goo.gl/forms/EeadABISlVmdJqgr2
